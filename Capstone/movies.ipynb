# %%
import pandas as pd

# %%
#Import Library Pandas

# %%
df.read_csv("Twitter-Oscars.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8d3eb0d72316> in <module>()
# ----> 1 df.read_csv("Twitter-Oscars.csv")
#
# NameError: name 'df' is not defined

# %%
import csv

# %%
import os.path

# %%
ls
# Out:
# Twitter- Oscars.csv            fandango_score_comparison.csv
# Untitled.ipynb                 fandango_scrape.csv
# avengers.csv                   marvel-wikia-data.csv
# daily_show_guests.csv          meta.csv
# data/                          movie_metadata.csv*
# dc-wikia-data.csv              tarantino.csv

# %%
open('Twitter-Oscars.csv')
# Out:
# <_io.TextIOWrapper name='Twitter-Oscars.csv' mode='r' encoding='UTF-8'>

# %%
# !cat Twitter-Oscars.csv

# %%
tweets = pd.read_csv('Twitter-Oscars.csv', sep=',' , encoding='latin-1')

# %%
list(tweets)
# Out:
# ['Date',
#  'Tweet Text',
#  'App',
#  'Followers',
#  'Follows',
#  'Retweets',
#  'Favorites',
#  'Verfied',
#  'User Since',
#  'Location']

# %%
import ggplot

# %%
import matplotlib

# %%
ggplot?

# %%
from ggplot import *
tweets.head()
# Out:
#                  Date                                         Tweet Text  \
# 0  2/27/2017 23:48:13  RT @deray: How Far I'll Go, Moana. feat. Auli'...
# 1  2/27/2017 23:48:13  RT @cosmos212: Será la foto de la década?? #os...
# 2  2/27/2017 23:48:13  RT @Muh_Sadam: #Oscars Ryan Gosling & Justin T...
# 3  2/27/2017 23:48:13  RT @Essence: Class. Excellence. Unmatched. #De...
# 4  2/27/2017 23:48:13  RT @rayliotta: Just heard what happened last n...
#
#                    App  Followers  Follows  Retweets  Favorites Verfied  \
# 0   Twitter for iPhone      397.0    295.0    6777.0        0.0      No
# 1   Twitter Web Client       67.0    119.0      77.0        0.0      No
# 2   Twitter for iPhone     1906.0   2366.0     542.0        0.0      No
# 3  Twitter for Windows     1879.0   1038.0     288.0        0.0      No
# 4   Twitter for iPhone      304.0    365.0   12754.0        0.0      No
#
#   User Since                 Location
# 0  8/16/2009               West Coast
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(tweets.Retweets, tweets.Location)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-dd6063bae9c9> in <module>()
# ----> 1 plt.scatter(tweets.Retweets, tweets.Location)
#
# /Users/kellyfowler/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# /Users/kellyfowler/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
print (movies.columns)
# Out:
# Index(['title', 'year', 'length', 'budget', 'rating', 'votes', 'r1', 'r2',
#        'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10', 'mpaa', 'Action',
#        'Animation', 'Comedy', 'Drama', 'Documentary', 'Romance', 'Short'],
#       dtype='object')

# %%
import pylab as p

# %%
C,S = movies.budget, movies.votes

p.plot(C,S)
p.show()

# %%
ggplot?

# %%
p = ggplot(aes(x='votes', y='budget'), data=movies)
print(p + geom_point())
# Out:
# <ggplot: (287835165)>

# %%
p = ggplot(aes(x='votes', y='length'), data=movies)
print(p + geom_point())
# Out:
# <ggplot: (288413248)>

# %%
Chart(movies).mark_bar().encode(x='budget', y='votes')

# %%
import altair

# %%
from altair import Chart, X, Y, Axis, SortField

# %%
movies_top_10 = movies.sort_values(by='votes',ascending=False)[:100]
movies_top_10.plot(kind='bar', x=movies.budget,
                   title='Facebook Likes by Budget',
                   legend=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-4c2dc31f9eb0> in <module>()
#       2 movies_top_10.plot(kind='bar', x=movies.budget,
#       3                    title='Facebook Likes by Budget',
# ----> 4                    legend=False)
#
# /Users/kellyfowler/anaconda/lib/python3.6/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
# ...
